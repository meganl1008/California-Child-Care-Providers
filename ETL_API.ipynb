# %% [markdown]
# # ETL for API

# %%
#install all libraries
# !pip install pandas
# !pip install sqlalchemy
# !pip install numpy
# !pip install splinter
# !pip install bs4
# !pip install ipython-sql

# %%
#import all libraries utilizied
import os
import csv
import pandas as pd
import json
from sqlalchemy import create_engine
import numpy as np
import requests

# %% [markdown]
# ## Extract data from API

# %%
# API url
url = "https://bw-interviews.herokuapp.com/data/providers"

# %%
# retrieve data and convert it into JSON
response = requests.get(url).json()

# pretty print the output of the JSON
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "providers": [
#         {
#             "email": "snfaria@ucdavis.edu",
#             "id": "prvdrs_xTVZPYTrIzsRBVJojkuHkRh6",
#             "owner_name": "Elizabeth Wall",
#             "phone": "(530) 753-8716",
#             "provider_name": "La Rue Park Child Development Center"
#         },
#         {
#             "email": "jane.uy@carouselschool.com",
#             "id": "prvdrs_9XYNilFfFjGeJjWbjP2uvLje",
#             "owner_name": "Shaneka Kittrell",
#             "phone": "(310) 216-6641",
#             "provider_name": "Carousel Preschool"
#         },
#         {
#             "email": "jrutledge@roseville.ca.us",
#             "id": "prvdrs_6fwq7dwGBVctHrZWbpBuZhWJ",
#             "owner_name": "Dewayne Bunning",
#             "phone": "(916) 772-7529",
#             "provider_name": "Adventure Club - Quail Glen"
#         },
#         {
#             "email": "vsisneroz@roseville.ca.us",
#             "id": "prvdrs_8YF3tyi0eeqlJm1UIeOZVx68",
#             "owner_name": "Ernest Edmondson",
#             "phone": "(916) 772-7271",
#             "provider_name": "Adventure Club - Coyote Ridge"
#         },
#         {
#             "email": "jhdmaddox60@msn.com",
#             "id": "prvdrs_nH2OzYh77wA1vs2aXsMqfNLx",
#             "owner_name": "William Bliss",
#             "phone": "(626) 334-1806",
#             "provider_name": "Azusa Discovery Center"
#         },
#         {
#             "email": "jmoore@fumcesc.com",
#             "id": "prvdrs_2iXXgefVvhsvGa3OXDPT6R4e",
#             "owner_name": "Gilbert Hernandez",
#             "phone": "(760) 745-6849",
#             "provider_name": "Light of Christ Children's Center"
#         },
#         {
#             "email": "lsfloren@yahoo.com",
#             "id": "prvdrs_JPVynpwpZVNG93k5ke12F3Pm",
#             "owner_name": "Essie Fernandez",
#             "phone": "(707) 445-0339",
#             "provider_name": "Little Peoples Corner Preschool/daycare"
#         },
#         {
#             "email": "301027@klcorp.com",
#             "id": "prvdrs_GoGNGJ1ZjWYWMVMv1jCAmwFX",
#             "owner_name": "James Middleton",
#             "phone": "(916) 961-5599",
#             "provider_name": "Kindercare Learning Center LLC"
#         },
#         {
#             "email": "wmayes@okcs.us",
#             "id": "prvdrs_bGYqJycansw3CycvVATrfpng",
#             "owner_name": "Gerald Sanyaro",
#             "phone": "(661) 393-3566",
#             "provider_name": "Olive Knolls Christian School"
#         },
#         {
#             "email": "peacepreschool10@yahoo.com",
#             "id": "prvdrs_YyqLv6sXMROfQ1GEtDH6Cs2h",
#             "owner_name": "Nathan Currie",
#             "phone": "(916) 927-4060",
#             "provider_name": "Peace Lutheran Early Childhood Education Center"
#         },
#         {
#             "email": "carol.allen@smusd.org",
#             "id": "prvdrs_3VZjKNPtMGFJM8qhaEN1FdE9",
#             "owner_name": "Alanna Schwartz",
#             "phone": "(760) 744-4776",
#             "provider_name": "Kids on Campus"
#         },
#         {
#             "email": "westreddingpreschool@ymail.com",
#             "id": "prvdrs_rVF4OIlRmKB8ha24qHNDPDuy",
#             "owner_name": "Morris Budd",
#             "phone": "(530) 243-2225",
#             "provider_name": "West Redding Preschool"
#         },
#         {
#             "email": "kiddieacademy1@aol.com",
#             "id": "prvdrs_SJzhwEqni6r7OdZBxkJfLLjC",
#             "owner_name": "Cesar Bowers",
#             "phone": "(760) 439-5552",
#             "provider_name": "Kiddie Academy Child Care Learning Center"
#         },
#         {
#             "email": "300886@klcorp.com",
#             "id": "prvdrs_c7P1KK1md0UZELOxRG5pse2q",
#             "owner_name": "Shelley Thomas",
#             "phone": "(760) 745-2474",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "Folsom@actiondaylearningcenter.com",
#             "id": "prvdrs_PLWjgHvIOLKifKVJLzsZKHXl",
#             "owner_name": "Oralia George",
#             "phone": "(916) 985-0976",
#             "provider_name": "Action Day Learning Center"
#         },
#         {
#             "email": "mmoreno@childtime.com",
#             "id": "prvdrs_XcbQHdHfyoQe6MxTiICOchhx",
#             "owner_name": "Orville Nelson",
#             "phone": "(661) 665-7790",
#             "provider_name": "Childtime Children's Center"
#         },
#         {
#             "email": "kmurphy@desertymca.org",
#             "id": "prvdrs_haX2r5oPhQpy47f3v6h2SfVA",
#             "owner_name": "John Newhouse",
#             "phone": "(760) 564-2848",
#             "provider_name": "La Quinta Preschool"
#         },
#         {
#             "email": "hrcc1@sbcglobal.net",
#             "id": "prvdrs_xiYaQGY8q7BjCy9uPytT6YW3",
#             "owner_name": "June Rolling",
#             "phone": "(530) 241-7226",
#             "provider_name": "Heather Ridge Child Care Center"
#         },
#         {
#             "email": "sstephens@childtime.com",
#             "id": "prvdrs_eF47uaHsJqTj73rx92hL2qGR",
#             "owner_name": "Robert Briscoe",
#             "phone": "(209) 551-0255",
#             "provider_name": "Childtime Children's Center"
#         },
#         {
#             "email": "MLais@roseville.ca.us",
#             "id": "prvdrs_pAuviSxNg3UbdlUvcxfj1XhA",
#             "owner_name": "Jospeh Bateman",
#             "phone": "(916) 773-3959",
#             "provider_name": "Adventure Club - Heritage Oak Elem. Sch."
#         },
#         {
#             "email": "000874@klcorp.com",
#             "id": "prvdrs_ZPVbGl36vx2fQ0373XigJEcw",
#             "owner_name": "Tracy Karathanasis",
#             "phone": "(805) 494-5152",
#             "provider_name": "KinderCare Learning Center"
#         },
#         {
#             "email": "dboneck@girlsincsb.org",
#             "id": "prvdrs_CIgCoOMOns05e3Bb1CGRDJYG",
#             "owner_name": "Henry Griffith",
#             "phone": "(805) 967-0319",
#             "provider_name": "Girls Inc. Of Greater North Santa Barbara"
#         },
#         {
#             "email": "301308@kc-education.com",
#             "id": "prvdrs_qIvAVY7hqmtfBH5z955o8FP9",
#             "owner_name": "Susan Snow",
#             "phone": "(951) 243-6558",
#             "provider_name": "KinderCare Education LLC"
#         },
#         {
#             "email": "treehouseprek2@gmail.com",
#             "id": "prvdrs_Sgaez9uqQr1wQ8dHuYw7o27y",
#             "owner_name": "Richard Cunningham",
#             "phone": "(209) 312-9449",
#             "provider_name": "Treehouse Christian Preschool 2"
#         },
#         {
#             "email": "sefidayschool@gmail.com",
#             "id": "prvdrs_7BnFRDNttxYs7TjXLkUls82n",
#             "owner_name": "David Adams",
#             "phone": "(619) 422-7115",
#             "provider_name": "Sefi Day School"
#         },
#         {
#             "email": "cthomas1@childtime.com",
#             "id": "prvdrs_gyuV11U8DINeVkXOi6Ipa1Nv",
#             "owner_name": "Allen Gonzales",
#             "phone": "(209) 545-1664",
#             "provider_name": "Childtime Children's Center"
#         },
#         {
#             "email": "tierrasanta@brighthorizons.com",
#             "id": "prvdrs_lrge1jShiNDjOhrb0FGV0ntj",
#             "owner_name": "Randy Queen",
#             "phone": "(858) 467-1800",
#             "provider_name": "Bright Horizons Tierrasanta"
#         },
#         {
#             "email": "Tammy.wells@nlcinc.com",
#             "id": "prvdrs_tCZUEwQzo7epq6XZTkJrSCTS",
#             "owner_name": "Clifford Welch",
#             "phone": "(209) 474-0518",
#             "provider_name": "Merryhill School"
#         },
#         {
#             "email": "300579@kindercare.com",
#             "id": "prvdrs_RjxRXrBR4jvIgLIWSvMJ3ssW",
#             "owner_name": "Robert Snipes",
#             "phone": "(714) 540-4750",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "0258@childtime.com",
#             "id": "prvdrs_dCO6NrYobWG8PRZTBVlsq4OK",
#             "owner_name": "Louis Rice",
#             "phone": "(951) 693-4843",
#             "provider_name": "Childtime Children's Center"
#         },
#         {
#             "email": "mishdharris16@yahoo.com",
#             "id": "prvdrs_0kd3dWZHixN6pwuRTCZsd9Mo",
#             "owner_name": "William Hargrove",
#             "phone": "(858) 586-7239",
#             "provider_name": "Michelle Harris Family Child Care"
#         },
#         {
#             "email": "7240@lpacorp.com",
#             "id": "prvdrs_e8hWC6qDqUGU1plin9od5j5Y",
#             "owner_name": "Shane Jaime",
#             "phone": "(858) 486-7197",
#             "provider_name": "La Petite Academy"
#         },
#         {
#             "email": "alejandrobarajas1965@gmail.com",
#             "id": "prvdrs_veRZnnOTw5z9BqL2LbVLQH4E",
#             "owner_name": "Janet Gamble",
#             "phone": "(714) 334-1531",
#             "provider_name": "Barajas Family Child Care"
#         },
#         {
#             "email": "site4@tutortime.com",
#             "id": "prvdrs_PsrVdv4YaV8OJWrGbrPmiko3",
#             "owner_name": "Melisa Gurrola",
#             "phone": "(909) 350-2422",
#             "provider_name": "Tutor Time Learning Center at Fontana"
#         },
#         {
#             "email": "300218@klcorp.com",
#             "id": "prvdrs_MKOnbS22MsWyoaYQ6goQCgfn",
#             "owner_name": "John Carty",
#             "phone": "(714) 774-5141",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "noahsarkvista@aol.com",
#             "id": "prvdrs_Y5bHpQLCkjzMC1OYuuXjV6Ab",
#             "owner_name": "Angel Cisneros",
#             "phone": "(760) 724-5445",
#             "provider_name": "Noahs Ark Learning Center"
#         },
#         {
#             "email": "speciallopez77@gmail.com",
#             "id": "prvdrs_my2yfhnEmOWdoqpZapvmqKMl",
#             "owner_name": "Jeffery Edwards",
#             "phone": "(831) 373-1922",
#             "provider_name": "Heaven Sent"
#         },
#         {
#             "email": "site7@tutortime.com",
#             "id": "prvdrs_FtVkzfNmdOlJ7YXtx4XmuNMV",
#             "owner_name": "Jean Jordan",
#             "phone": "(951) 461-7900",
#             "provider_name": "Tutor Time Child Care/Learning Center"
#         },
#         {
#             "email": "n_kang07@yahoo.com",
#             "id": "prvdrs_DIJ4ceprYLcY1zKeO6wVeVPc",
#             "owner_name": "Brian Rybka",
#             "phone": "(530) 674-5991",
#             "provider_name": "Narinder Family Child Care Home"
#         },
#         {
#             "email": "ecollazo@abcvillage.com",
#             "id": "prvdrs_ZwOUKkzX3IbfwRYWmB4mBPRZ",
#             "owner_name": "Margaret Rann",
#             "phone": "(951) 491-0940",
#             "provider_name": "ABC Child Care Village"
#         },
#         {
#             "email": "ktoca@abccares.com",
#             "id": "prvdrs_VO5AtUmTRCwlwwJ0FtgDLEi7",
#             "owner_name": "Jean Joyner",
#             "phone": "(951) 699-5251",
#             "provider_name": "ABC Child Care"
#         },
#         {
#             "email": "gonzalezdaycare@sbcglobal.net",
#             "id": "prvdrs_PntaCLAhjFsdjf7Br4wo1GoG",
#             "owner_name": "Stephen Helton",
#             "phone": "(760) 631-2674",
#             "provider_name": "Gonzalez Haydee Family Child Care"
#         },
#         {
#             "email": "7241@lapetite.com",
#             "id": "prvdrs_AVSVjBcAyXjBsttc9mHsSO4J",
#             "owner_name": "Wanda Bell",
#             "phone": "(760) 727-0648",
#             "provider_name": "La Petite Academy at Vista"
#         },
#         {
#             "email": "mbaguilar@ymca.org",
#             "id": "prvdrs_R28SIwiSSBxDNbMM97X21ReA",
#             "owner_name": "Lisa Siddoway",
#             "phone": "(858) 453-3483",
#             "provider_name": "La Jolla Family YMCA- Torrey Pines Elementary"
#         },
#         {
#             "email": "janet27lowej@yahoo.com",
#             "id": "prvdrs_Dv3fK8yl98ES5wuX8skVU7rd",
#             "owner_name": "George Whitfield",
#             "phone": "(760) 724-9246",
#             "provider_name": "Janet Anseline Welsh"
#         },
#         {
#             "email": "garzae@cox.net",
#             "id": "prvdrs_EOfEpLO3HSiaZiMjpbBuY6Sg",
#             "owner_name": "Gabriel Chestnut",
#             "phone": "(760) 724-2759",
#             "provider_name": "Elizabeth Garza Family Child Care"
#         },
#         {
#             "email": "7202@lapetite.com",
#             "id": "prvdrs_yDCUK48XSnmI8BLPd40DmNvc",
#             "owner_name": "Hazel Trahan",
#             "phone": "(909) 860-4009",
#             "provider_name": "La Petite Academy Inc-Grand Ave"
#         },
#         {
#             "email": "careysciotto@cox.net",
#             "id": "prvdrs_x7XWD0DDDPgXTo5vbqEj3Z9f",
#             "owner_name": "Joe Gonzalez",
#             "phone": "(619) 469-7281",
#             "provider_name": "Merry Go Round Learning Center"
#         },
#         {
#             "email": "pjwoogie@live.com",
#             "id": "prvdrs_eAsRWo4Uvb2AbFMoe3M8rQ4T",
#             "owner_name": "Gabrielle Ruddell",
#             "phone": "(760) 806-4710",
#             "provider_name": "Eberly Day Care"
#         },
#         {
#             "email": "301034@klcorp.com",
#             "id": "prvdrs_IIEKsN1WXsx4i2YedaoGpB5U",
#             "owner_name": "Mary Barringer",
#             "phone": "(707) 426-2275",
#             "provider_name": "KinderCare Learning Centers LLC"
#         },
#         {
#             "email": "cthomas1@childtime.com",
#             "id": "prvdrs_EQc6rgaAzoUsCVPjONn7QMl4",
#             "owner_name": "Alvin Chavez",
#             "phone": "(209) 545-1664",
#             "provider_name": "Childtime Children's Center"
#         },
#         {
#             "email": "tierrasanta@brighthorizons.com",
#             "id": "prvdrs_wZKlkOGzpt6hagqaVLShqrRF",
#             "owner_name": "Pamela Martinez",
#             "phone": "(858) 467-1800",
#             "provider_name": "Bright Horizons Tierrasanta"
#         },
#         {
#             "email": "Tammy.wells@nlcinc.com",
#             "id": "prvdrs_GEMfa8jXh4JTSaSITZz4Gqel",
#             "owner_name": "Carol Warnstaff",
#             "phone": "(209) 474-0518",
#             "provider_name": "Merryhill School"
#         },
#         {
#             "email": "300579@kindercare.com",
#             "id": "prvdrs_C8S3ztJG8fvinfGVjZxDARVd",
#             "owner_name": "Amy Haber",
#             "phone": "(714) 540-4750",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "0258@childtime.com",
#             "id": "prvdrs_0VhGLM2YUUbUOujWafFOMVt6",
#             "owner_name": "Elvin Adams",
#             "phone": "(951) 693-4843",
#             "provider_name": "Childtime Children's Center"
#         },
#         {
#             "email": "mishdharris16@yahoo.com",
#             "id": "prvdrs_5rJFJosJKaZfxbER6pvUkg1L",
#             "owner_name": "Troy Brown",
#             "phone": "(858) 586-7239",
#             "provider_name": "Michelle Harris Family Child Care"
#         },
#         {
#             "email": "7240@lpacorp.com",
#             "id": "prvdrs_MGjilcoqU85nwx7HYgwWIBxN",
#             "owner_name": "Regina Smith",
#             "phone": "(858) 486-7197",
#             "provider_name": "La Petite Academy"
#         },
#         {
#             "email": "alejandrobarajas1965@gmail.com",
#             "id": "prvdrs_1trlas7w8qftTVjydpmantrM",
#             "owner_name": "Christine Payne",
#             "phone": "(714) 334-1531",
#             "provider_name": "Barajas Family Child Care"
#         },
#         {
#             "email": "site4@tutortime.com",
#             "id": "prvdrs_aosszqG0k8lL1sJ9jy3DUmC8",
#             "owner_name": "Heather Elson",
#             "phone": "(909) 350-2422",
#             "provider_name": "Tutor Time Learning Center at Fontana"
#         },
#         {
#             "email": "300218@klcorp.com",
#             "id": "prvdrs_cyiQsamTPeMPVcPGkCbl5uuo",
#             "owner_name": "Debra Trujillo",
#             "phone": "(714) 774-5141",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "noahsarkvista@aol.com",
#             "id": "prvdrs_tx2OkEVNDEm6pZZFEvejY4yJ",
#             "owner_name": "Lynette Calderon",
#             "phone": "(760) 724-5445",
#             "provider_name": "Noahs Ark Learning Center"
#         },
#         {
#             "email": "speciallopez77@gmail.com",
#             "id": "prvdrs_Gb5LVz9PwBnhPJ5dYrjNRJcf",
#             "owner_name": "Josephine Hollowell",
#             "phone": "(831) 373-1922",
#             "provider_name": "Heaven Sent"
#         },
#         {
#             "email": "site7@tutortime.com",
#             "id": "prvdrs_FHOnLO7byCwVB6u8Iiph2uLa",
#             "owner_name": "Jerome Knight",
#             "phone": "(951) 461-7900",
#             "provider_name": "Tutor Time Child Care/Learning Center"
#         },
#         {
#             "email": "n_kang07@yahoo.com",
#             "id": "prvdrs_l4xDNascrIPEfWpfimBts62B",
#             "owner_name": "Linda Sallee",
#             "phone": "(530) 674-5991",
#             "provider_name": "Narinder Family Child Care Home"
#         },
#         {
#             "email": "ecollazo@abcvillage.com",
#             "id": "prvdrs_nrsqlDRYIPle0eHsvg6cDvIv",
#             "owner_name": "Jose Dudley",
#             "phone": "(951) 491-0940",
#             "provider_name": "ABC Child Care Village"
#         },
#         {
#             "email": "ktoca@abccares.com",
#             "id": "prvdrs_iSobYqmMieDUse3A3np4S7vP",
#             "owner_name": "Dusty Simon",
#             "phone": "(951) 699-5251",
#             "provider_name": "ABC Child Care"
#         },
#         {
#             "email": "gonzalezdaycare@sbcglobal.net",
#             "id": "prvdrs_n312yJwhlmJKd5gMkuqcYsnc",
#             "owner_name": "Melinda Hill",
#             "phone": "(760) 631-2674",
#             "provider_name": "Gonzalez Haydee Family Child Care"
#         },
#         {
#             "email": "7241@lapetite.com",
#             "id": "prvdrs_hcfAjcYYeaZdtWLfJd0wjgJU",
#             "owner_name": "Clara Locklear",
#             "phone": "(760) 727-0648",
#             "provider_name": "La Petite Academy at Vista"
#         },
#         {
#             "email": "mbaguilar@ymca.org",
#             "id": "prvdrs_bA7A3umkXStH5Tpj3PNwvhcG",
#             "owner_name": "Raymond Blair",
#             "phone": "(858) 453-3483",
#             "provider_name": "La Jolla Family YMCA- Torrey Pines Elementary"
#         },
#         {
#             "email": "janet27lowej@yahoo.com",
#             "id": "prvdrs_McD6JWZugg5jbrT9KOQPqG9u",
#             "owner_name": "Christopher Ewy",
#             "phone": "(760) 724-9246",
#             "provider_name": "Janet Anseline Welsh"
#         },
#         {
#             "email": "garzae@cox.net",
#             "id": "prvdrs_fVrcEUra75fQcGLIwR2XJVgd",
#             "owner_name": "Casey Cohen",
#             "phone": "(760) 724-2759",
#             "provider_name": "Elizabeth Garza Family Child Care"
#         },
#         {
#             "email": "7202@lapetite.com",
#             "id": "prvdrs_t83lOBf4hXgu2YV8dBYGRuYO",
#             "owner_name": "Patricia Neely",
#             "phone": "(909) 860-4009",
#             "provider_name": "La Petite Academy Inc-Grand Ave"
#         },
#         {
#             "email": "careysciotto@cox.net",
#             "id": "prvdrs_Lave7cI1kLl9XSDEzsA2RfA5",
#             "owner_name": "George Smith",
#             "phone": "(619) 469-7281",
#             "provider_name": "Merry Go Round Learning Center"
#         },
#         {
#             "email": "pjwoogie@live.com",
#             "id": "prvdrs_qjLIdufyVbecFwczIP8orL4r",
#             "owner_name": "Jo Rodriquez",
#             "phone": "(760) 806-4710",
#             "provider_name": "Eberly Day Care"
#         },
#         {
#             "email": "301034@klcorp.com",
#             "id": "prvdrs_EDsfs4ljm72Q2hQXK49Z1mYJ",
#             "owner_name": "Matthew Zamora",
#             "phone": "(707) 426-2275",
#             "provider_name": "KinderCare Learning Centers LLC"
#         },
#         {
#             "email": "sbixler@bgchv.com",
#             "id": "prvdrs_Bh833CuHPnwIri2eq45rlVP6",
#             "owner_name": "Roger Bell",
#             "phone": "(714) 593-0753",
#             "provider_name": "Learning Center Child Development Preschool"
#         },
#         {
#             "email": "lmomongan@ivycrest.org",
#             "id": "prvdrs_ZYfaLEsWv2ZyEUGdIEv9wxnm",
#             "owner_name": "Ira Perun",
#             "phone": "(714) 879-6091",
#             "provider_name": "Ivy Crest Montessori Private School"
#         },
#         {
#             "email": "301172@klcorp.com",
#             "id": "prvdrs_2sfoN5uwdaXxpQUlS4kgY1Kp",
#             "owner_name": "Melanie Jenson",
#             "phone": "(909) 599-0597",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "ginger@kidscareclub.com",
#             "id": "prvdrs_FGzBFmyHfd64i11MbYKRypDR",
#             "owner_name": "Stacey Nichols",
#             "phone": "(858) 538-5437",
#             "provider_name": "Kids' Care Club"
#         },
#         {
#             "email": "301126@klcorp.com",
#             "id": "prvdrs_tx8SySIDiIPw6OEl2KpkLq7x",
#             "owner_name": "Russell Edmundson",
#             "phone": "(707) 447-7685",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "303039@klcorp.com",
#             "id": "prvdrs_PRPNHcoBawdYPvm7FB4KZJ6b",
#             "owner_name": "James Thomas",
#             "phone": "(949) 551-6808",
#             "provider_name": "Kindercare Learning Center LLC"
#         },
#         {
#             "email": "emikorodriguez@gmail.com",
#             "id": "prvdrs_dvMymTwBuLZCxONYL17kxtrC",
#             "owner_name": "David Oconnell",
#             "phone": "(858) 486-4420",
#             "provider_name": "Poway Country Preschool"
#         },
#         {
#             "email": null,
#             "id": "prvdrs_5wWeFcGsYcrL6nW1A6E8Ubfq",
#             "owner_name": "Leonard Reaves",
#             "phone": "(562) 943-8332",
#             "provider_name": "Hillcrest Country Day School"
#         },
#         {
#             "email": "hobbledehoymontessoripreschool@gmail.com",
#             "id": "prvdrs_cmbagTmlQJQfwgYVJQqPENQO",
#             "owner_name": "Paul Nelson",
#             "phone": "(650) 968-1155",
#             "provider_name": "Hobbledehoy Montessori Preschool"
#         },
#         {
#             "email": "susanna.herbst@brighthorizons.com",
#             "id": "prvdrs_TeWyFCoryQSfsFRJYryVYX1r",
#             "owner_name": "Tammy Romero",
#             "phone": "(619) 539-5569",
#             "provider_name": "Barry Ted Moskowitz Child Care Center"
#         },
#         {
#             "email": "mont028@sbcglobal.net",
#             "id": "prvdrs_xrGCGgajL7iaJXTJwvyqBQAj",
#             "owner_name": "Kathy Morgan",
#             "phone": "(858) 505-0332",
#             "provider_name": "Montessori School of Kearny Mesa"
#         },
#         {
#             "email": "7234@lapetite.com",
#             "id": "prvdrs_I9FqgHie9yrPfS91ZqbsO5CL",
#             "owner_name": "Steven Jacobson",
#             "phone": "(619) 421-0966",
#             "provider_name": "La Petite Academy - East J"
#         },
#         {
#             "email": "301358@klcorp.com",
#             "id": "prvdrs_0BCBbMuuVBlCRUqaTiz9B8Ak",
#             "owner_name": "Eric Carter",
#             "phone": "(916) 682-1111",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "nlds1985@yahoo.com",
#             "id": "prvdrs_zldNqpir1u3cHxXl9IxbmpCG",
#             "owner_name": "Sarah Mathews",
#             "phone": "(559) 229-8687",
#             "provider_name": "New Life Figarden School"
#         },
#         {
#             "email": "300897@klcorp.com",
#             "id": "prvdrs_XCPiKZTKM7hDwQ4xL7ac67OF",
#             "owner_name": "Lester Deleon",
#             "phone": "(619) 562-3423",
#             "provider_name": "Kindercare Learning Center LLC"
#         },
#         {
#             "email": "0224@childtime.com",
#             "id": "prvdrs_QNpDC2TjEsTYSwso4a2117xN",
#             "owner_name": "April Stone",
#             "phone": "(951) 242-0707",
#             "provider_name": "Childtime Children's Center"
#         },
#         {
#             "email": "mc-daycare@hotmail.com",
#             "id": "prvdrs_EYzJgOY6kOJxRmhffBE977xB",
#             "owner_name": "Fatimah Young",
#             "phone": "(619) 583-7180",
#             "provider_name": "Campos Maritza Family Child Care"
#         },
#         {
#             "email": "preciouslambs87@gmail.com",
#             "id": "prvdrs_hzBj6A6Ki6ePUDVFbpD3cuiI",
#             "owner_name": "Richard Haynes",
#             "phone": "(619) 565-8667",
#             "provider_name": "Brown Family Child Care"
#         },
#         {
#             "email": "301770@klcorp.com",
#             "id": "prvdrs_5wQD4ONlOZVVicpRiTqCgMSI",
#             "owner_name": "Brian Mcdaniel",
#             "phone": "(619) 656-9853",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "sunshinehouseLV@gmail.com",
#             "id": "prvdrs_CeLnZ36f0Xr4vFqKoMpXxeyg",
#             "owner_name": "Charles Carsey",
#             "phone": "(925) 513-1113",
#             "provider_name": "Sunshine House - Loma Vista Kid Zone"
#         },
#         {
#             "email": "sylviaalvareztostado@gmail.com",
#             "id": "prvdrs_9ptpCL8O1TCaWIGWp8alNR6C",
#             "owner_name": "Kevin Pang",
#             "phone": "(619) 575-6791",
#             "provider_name": "Sylvia Alvarez-Tostado"
#         },
#         {
#             "email": "kids4everfamily@yahoo.com",
#             "id": "prvdrs_nvklajSjZMZmhgAiANJgfYDV",
#             "owner_name": "Josefina Sharp",
#             "phone": "(619) 527-0463",
#             "provider_name": "Paulette Johnson"
#         },
#         {
#             "email": "7216@lapetite.com",
#             "id": "prvdrs_gnH5FNH3J2otkHdLdD7LtI44",
#             "owner_name": "Tanya Hoffman",
#             "phone": "(209) 368-0303",
#             "provider_name": "La Petite Academy Inc"
#         },
#         {
#             "email": "301697@klcorp.com",
#             "id": "prvdrs_eMkLvyqcm8h2Vy5p1tjlBN7o",
#             "owner_name": "Keith Jordan",
#             "phone": "(916) 353-0687",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "kristi.polk@nlcinc.com",
#             "id": "prvdrs_aEAVWDZBaKWWJM96Uq81pDpp",
#             "owner_name": "Clarence Meeks",
#             "phone": "(951) 303-3055",
#             "provider_name": "Discovery Isle Child Development Center"
#         },
#         {
#             "email": "cherylroberts5615@att.net",
#             "id": "prvdrs_7ZbJxi8YwH3TVce6xBcGXkM2",
#             "owner_name": "Tony Hornyak",
#             "phone": "(805) 238-0200",
#             "provider_name": "STARS Preschool"
#         },
#         {
#             "email": "303073@klcorp.com",
#             "id": "prvdrs_bU3RitHpTt9RcGzYY324fgAd",
#             "owner_name": "Teresa Martinez",
#             "phone": "(619) 482-1800",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "301051@klcorp.com",
#             "id": "prvdrs_rltOXHR9lUaUOrKrlTJNkJwI",
#             "owner_name": "Drusilla Nord",
#             "phone": "(209) 835-9247",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "303002@klcorp.com",
#             "id": "prvdrs_MyM2fWfWIavprNydrZ8GRT8D",
#             "owner_name": "Carlos Perry",
#             "phone": "(951) 943-6476",
#             "provider_name": "Kindercare Learning Center LLC"
#         },
#         {
#             "email": "ap@bradshawchristian.com",
#             "id": "prvdrs_wRagkXz7WM9CsoiBPe1H21us",
#             "owner_name": "Rafael Stephens",
#             "phone": "(916) 688-0521",
#             "provider_name": "Bradshaw Christian School"
#         },
#         {
#             "email": "Achildsplace0687@cox.net",
#             "id": "prvdrs_a392WHFTipASNAZtVi5OYnax",
#             "owner_name": "Roberto Keen",
#             "phone": "(619) 621-1764",
#             "provider_name": "Owensbrown, Stephanie Family Child Care"
#         },
#         {
#             "email": "avannoory@yahoo.com",
#             "id": "prvdrs_SbFTcANCEWEknTEWJOygXYZ3",
#             "owner_name": "James Trentman",
#             "phone": "(619) 947-9190",
#             "provider_name": "Avan Family Child Care"
#         },
#         {
#             "email": "300782@klcorp.com",
#             "id": "prvdrs_HeSpS3nue3PHDmTRJhC7BQcU",
#             "owner_name": "Kathy Coplin",
#             "phone": "(951) 924-1956",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "anitasalvador05@yahoo.com",
#             "id": "prvdrs_ncBLBkPSQrIsu6nZ9DpMzJoI",
#             "owner_name": "Arnold Young",
#             "phone": "(858) 467-9821",
#             "provider_name": "Salvador, Ariel & Anita Family Child Care"
#         },
#         {
#             "email": "cflores-gonzalez@ymca.org",
#             "id": "prvdrs_21PDR2hFesapd0I4rbwmhlLq",
#             "owner_name": "Bonnie Ramos",
#             "phone": "(619) 280-9622",
#             "provider_name": "Copley Family YMCA - Central Elementary-Preschool"
#         },
#         {
#             "email": "ssciortino@ymcaoc.org",
#             "id": "prvdrs_yBDyV2HW3gjUjSjOLKEyKW3C",
#             "owner_name": "William Cannon",
#             "phone": "(949) 542-3904",
#             "provider_name": "South Coast YMCA-Hidden Hills"
#         },
#         {
#             "email": "abckidsrb@att.net",
#             "id": "prvdrs_81yplKgkVtj1v1XyiITRjDp5",
#             "owner_name": "Jeffrey Deluca",
#             "phone": "(858) 451-1663",
#             "provider_name": "ABC Childrens Center of Rancho Bernardo"
#         },
#         {
#             "email": "301458@klcorp.com",
#             "id": "prvdrs_X44ra84i83YuNEfs9Pt5RS49",
#             "owner_name": "Mary Cowans",
#             "phone": "(951) 696-0825",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "auntiefatima@gmail.com",
#             "id": "prvdrs_DT6gZPVbxOi2LZPuN6NF6SAo",
#             "owner_name": "Celia Sheldon",
#             "phone": "(619) 226-2275",
#             "provider_name": "Maria Tanita"
#         },
#         {
#             "email": "froggiemee79@gmail.com",
#             "id": "prvdrs_kXaUjQaHUe94mEmuHLpeZVXi",
#             "owner_name": "Jackie Miller",
#             "phone": "(818) 318-6915",
#             "provider_name": "Robinson Tanner, Ericka Family Child Care"
#         },
#         {
#             "email": "jgreenawald@calvarysd.com",
#             "id": "prvdrs_uSnMurVeP6A9WjQ1OZ6Bns65",
#             "owner_name": "Hillary Gross",
#             "phone": "(619) 591-2260",
#             "provider_name": "Calvary Christian Academy"
#         },
#         {
#             "email": "ShannysLp@gmail.com",
#             "id": "prvdrs_EvinRHWMiJidBEIaKSjrCAsa",
#             "owner_name": "Vera Drake",
#             "phone": "(619) 952-6997",
#             "provider_name": "Shantell Padilla Family Child Care"
#         },
#         {
#             "email": "301634@klcorp.com",
#             "id": "prvdrs_jxlXqrb4nLrFbOcLhLytZHTt",
#             "owner_name": "Jean Darrin",
#             "phone": "(760) 435-0001",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "diane@weecarepreschools.com",
#             "id": "prvdrs_jDlvMdV6bHdS9GXwbPCDnoYW",
#             "owner_name": "Horace Cobb",
#             "phone": "(858) 560-0985",
#             "provider_name": "Wee Care Preschool"
#         },
#         {
#             "email": "lorij@nglc.org",
#             "id": "prvdrs_AXPioscX6OTS2yZeHD7QTdN5",
#             "owner_name": "Stacy Watson",
#             "phone": "(858) 271-9878",
#             "provider_name": "New Generations Learning Center Plus"
#         },
#         {
#             "email": "000650@klcorp.com",
#             "id": "prvdrs_4aIrPpNYNnICgujmJDFLCo0T",
#             "owner_name": "Jerry Steagell",
#             "phone": "(858) 672-1200",
#             "provider_name": "KinderCare Education LLC"
#         },
#         {
#             "email": "srodriguez3@lapetite.com",
#             "id": "prvdrs_27tVkHaoqrgGi4o6r7IX22KL",
#             "owner_name": "Phillip Boudreaux",
#             "phone": "(760) 941-5406",
#             "provider_name": "La Petite Academy at Oceanside"
#         },
#         {
#             "email": "000743@klcorp.com",
#             "id": "prvdrs_FZhROhuRoowZ6XOxP4E883Ez",
#             "owner_name": "Fay Davis",
#             "phone": "(858) 271-4700",
#             "provider_name": "KinderCare Education LLC"
#         },
#         {
#             "email": "apple2@cox.net",
#             "id": "prvdrs_AVXCXsXmSFEqv9IkxFK4mh2C",
#             "owner_name": "James Murray",
#             "phone": "(619) 420-2046",
#             "provider_name": "Community Congregational Church"
#         },
#         {
#             "email": "ldaniels9@cox.net",
#             "id": "prvdrs_mGJuJXuS3TeaLCNnRaeNkw8i",
#             "owner_name": "Lisa Neverson",
#             "phone": "(619) 460-6432",
#             "provider_name": "Lisa's Lil Tikes Preschool"
#         },
#         {
#             "email": "msopto@yahoo.com",
#             "id": "prvdrs_CRmy9oAv5UqN2mq5FVfah3O8",
#             "owner_name": "Clyde Fetter",
#             "phone": "(760) 941-3883",
#             "provider_name": "Montessori School of Oceanside"
#         },
#         {
#             "email": "0259@childtime.com",
#             "id": "prvdrs_d4VO1d6D5tCEiMAmq2Bsn1x3",
#             "owner_name": "Matthew Bakken",
#             "phone": "(805) 983-7779",
#             "provider_name": "Childtime Learning Center"
#         },
#         {
#             "email": "claire.hung@ameschildcare.org",
#             "id": "prvdrs_WdeEg3MK7ri8UoLZiXnQtxEk",
#             "owner_name": "Kerri Davis",
#             "phone": "(650) 604-5100",
#             "provider_name": "Ames Child Care Center"
#         },
#         {
#             "email": "christine.harrah@nlcinc.com",
#             "id": "prvdrs_0PdnQbrwFWBvZWGfOxnsn9SV",
#             "owner_name": "Rosie Gilmore",
#             "phone": "(916) 285-8656",
#             "provider_name": "Merryhill School-Danbrook"
#         },
#         {
#             "email": "jadams337@aol.com",
#             "id": "prvdrs_fGwZFBKFZx30ZuwoR8j0e0g3",
#             "owner_name": "James Huard",
#             "phone": "(619) 752-6007",
#             "provider_name": "Josephine Allen Family Childcare"
#         },
#         {
#             "email": "angelica69@san.rr.com",
#             "id": "prvdrs_yUvlcPHIfErtPC9yACyi7vXY",
#             "owner_name": "Jeffery Blankenship",
#             "phone": "(858) 536-5991",
#             "provider_name": "Angelica's Childcare"
#         },
#         {
#             "email": "tbasanec@gmail.com",
#             "id": "prvdrs_4HYiIFlGji2M7KemYWhwiqvs",
#             "owner_name": "Carol Pigman",
#             "phone": "(858) 693-3702",
#             "provider_name": "Scripps Exploring Academy"
#         },
#         {
#             "email": "0256@childtime.com",
#             "id": "prvdrs_3ubAq9iuQHeiWQyF91bGLG3t",
#             "owner_name": "Tracy Baker",
#             "phone": "(760) 967-5846",
#             "provider_name": "Childtime Children's Center"
#         },
#         {
#             "email": "books.mather@gmail.com",
#             "id": "prvdrs_mkqVbmOdiznZ8VUZm9HJYGYh",
#             "owner_name": "William Smith",
#             "phone": "(916) 366-5800",
#             "provider_name": "Rosemont Playschool, Inc., Mather Playschool"
#         },
#         {
#             "email": "0255@childtime.com",
#             "id": "prvdrs_IBxdR2XFmPkNC91u8oUHLyp8",
#             "owner_name": "Johnny Lemaster",
#             "phone": "(619) 397-0165",
#             "provider_name": "Childtime Children's Center-Chula Vista"
#         },
#         {
#             "email": "castlekids123@yahoo.com",
#             "id": "prvdrs_78RgO0OgBMKcOsrBHcYUkZOt",
#             "owner_name": "Alvin Mulroy",
#             "phone": "(530) 892-2273",
#             "provider_name": "Castles Preschool"
#         },
#         {
#             "email": "301224@klcorp.com",
#             "id": "prvdrs_OsAjr1ry9JfXJ4EUQY7oRyzi",
#             "owner_name": "Jimmy Doan",
#             "phone": "(951) 683-1626",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "ashley.kerr@nlcinc.com",
#             "id": "prvdrs_aYDL8bFWUPGMQ7LZQ17j5LEV",
#             "owner_name": "Julie Mckay",
#             "phone": "(951) 304-3033",
#             "provider_name": "Discovery Isle Child Development Center"
#         },
#         {
#             "email": "cdc@swccd.edu",
#             "id": "prvdrs_tLLLJL4tsHG1tVXOumkMu7vL",
#             "owner_name": "George Baker",
#             "phone": "(619) 216-6695",
#             "provider_name": "Southwestern College Child Development Center"
#         },
#         {
#             "email": "Tobi@kidscareclub.com",
#             "id": "prvdrs_825DNIiHd4cwPgqIy7JscpHX",
#             "owner_name": "Sonia Allen",
#             "phone": "(858) 675-7000",
#             "provider_name": "Kids' Care Club"
#         },
#         {
#             "email": "admin@bonitacountryday.org",
#             "id": "prvdrs_d2tY9otHrxUEHDVuH8rgpiyn",
#             "owner_name": "Mary Jones",
#             "phone": "(619) 656-0141",
#             "provider_name": "Bonita Country Day School"
#         },
#         {
#             "email": "301062@klcorp.com",
#             "id": "prvdrs_pHgS7x0kztJ9iCPaBtoS7LMO",
#             "owner_name": "Tyler Koop",
#             "phone": "(760) 940-2008",
#             "provider_name": "Kindercare Learning Center LLC"
#         },
#         {
#             "email": "acrosby@missionnaz.org",
#             "id": "prvdrs_TE5Jw37mKnFSlFDl9WtriKRt",
#             "owner_name": "Jason Hanners",
#             "phone": "(619) 287-3211",
#             "provider_name": "Mission Nazarene Child Care Center"
#         },
#         {
#             "email": "sremers@lsusd.net",
#             "id": "prvdrs_EGMLbij5wnOtrVfCJue4ArpI",
#             "owner_name": "Laurie Brueggeman",
#             "phone": "(619) 390-2534",
#             "provider_name": "LUSD Lemon Crest Elementary"
#         },
#         {
#             "email": "khaupt1@tvusd.k12.ca.us",
#             "id": "prvdrs_OjA74b2IsOdU7NZ4Bww3ScFk",
#             "owner_name": "Jennifer Lang",
#             "phone": "(951) 506-7061",
#             "provider_name": "LaVorgna BASES"
#         },
#         {
#             "email": "maribelsdaycare1@yahoo.com",
#             "id": "prvdrs_Xtphle0APAITlJldhP8omhrx",
#             "owner_name": "Gene Munoz",
#             "phone": "(760) 696-8488",
#             "provider_name": "Reyes, Maribel Family Child Care"
#         },
#         {
#             "email": "lincolnic@actiondayprimaryplus.com",
#             "id": "prvdrs_eo17SGrzAhhwMh7lrOFdi1HQ",
#             "owner_name": "Mario Walters",
#             "phone": "(408) 266-8188",
#             "provider_name": "Action Day Primary Plus- Infant Center"
#         },
#         {
#             "email": "301566@klcorp.com",
#             "id": "prvdrs_QPED77BlvCsNSkNdS5Zpmgbe",
#             "owner_name": "Debbi Anderson",
#             "phone": "(916) 772-5252",
#             "provider_name": "Kindercare Learning Center LLC"
#         },
#         {
#             "email": "mmoser@horizonsd.org",
#             "id": "prvdrs_6qHorYEIyTV5ZgqVtksMVHzx",
#             "owner_name": "Milo Emmons",
#             "phone": "(858) 277-9376",
#             "provider_name": "Horizon Christian Preschool"
#         },
#         {
#             "email": "301645@klcorp.com",
#             "id": "prvdrs_MZn9HPnMG6B8ePRdswiSdaxX",
#             "owner_name": "David Dale",
#             "phone": "(805) 445-8485",
#             "provider_name": "KinderCare Learning Centers LLC"
#         },
#         {
#             "email": "monique.acosta@klcorp.com",
#             "id": "prvdrs_Kqtp8tnUTcek2S7IXIQChrpZ",
#             "owner_name": "Carrie Aumick",
#             "phone": "(909) 945-9381",
#             "provider_name": "KinderCare Learning Center"
#         },
#         {
#             "email": "sremers@lsusd.net",
#             "id": "prvdrs_oY2S800SrtI0n7UHj92lb949",
#             "owner_name": "Solomon Potter",
#             "phone": "(619) 390-2534",
#             "provider_name": "Marilla-Lakeside Early Advantage Preschool"
#         },
#         {
#             "email": "sremers@lsusd.net",
#             "id": "prvdrs_RUL8MBiBjkdrleKdYddMk8dU",
#             "owner_name": "Jeffrey Melvin",
#             "phone": "(619) 390-2534",
#             "provider_name": "LUSD @ Winter Gardens"
#         },
#         {
#             "email": "sremers@lsusd.net",
#             "id": "prvdrs_HgFspJ1GnMPBX8MHs09eeTIC",
#             "owner_name": "Adrian Konecny",
#             "phone": "(619) 390-2534",
#             "provider_name": "LUSD ESS Lakeview Center"
#         },
#         {
#             "email": "sremers@lsusd.net",
#             "id": "prvdrs_7uYr3DMKsbDiuEzibOt9WGQQ",
#             "owner_name": "Johnny Dickens",
#             "phone": "(619) 390-2534",
#             "provider_name": "LUSD Lindo Park"
#         },
#         {
#             "email": "301580@klcorp.com",
#             "id": "prvdrs_GY5u3M7AIf2LsNgmytVt8Udj",
#             "owner_name": "Daniel Elkins",
#             "phone": "(916) 315-3399",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "MClaub@cox.net",
#             "id": "prvdrs_tXsQnIq3ruxtH54Zk6udTbQS",
#             "owner_name": "Robert Chandler",
#             "phone": "(619) 561-0902",
#             "provider_name": "Montessori East County Preschool - Preschool Location"
#         },
#         {
#             "email": "lisa.sporl@nlcinc.com",
#             "id": "prvdrs_UvMcQ0MJXEjKXaOPVMJmRNMC",
#             "owner_name": "Deborah Ficklin",
#             "phone": "(858) 536-1400",
#             "provider_name": "Discovery Isle Child Development Center"
#         },
#         {
#             "email": "300466@klcorp.com",
#             "id": "prvdrs_THpwsGPNClzclLvJafd8G2Wl",
#             "owner_name": "Samuel Romano",
#             "phone": "(858) 453-7530",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "mhart@powayusd.com",
#             "id": "prvdrs_OpYpDu2gCrd483RKoRwamrtN",
#             "owner_name": "Danny Noble",
#             "phone": "(878) 748-0010",
#             "provider_name": "Sunset Hills ESS Program"
#         },
#         {
#             "email": "berumenmib@aol.com",
#             "id": "prvdrs_XYVna2Zyr8n52plEhOJpRkAG",
#             "owner_name": "Judy James",
#             "phone": "(760) 730-5306",
#             "provider_name": "Berumen Day Care"
#         },
#         {
#             "email": "yvette@merrygoaround.org",
#             "id": "prvdrs_B6qyykMWIqLsstrk2fo4VaJC",
#             "owner_name": "Johnny Staples",
#             "phone": "(858) 536-1008",
#             "provider_name": "Merry Go Around"
#         },
#         {
#             "email": "Soniadagni@aol.com",
#             "id": "prvdrs_zb2RMChXJXWHIrobi9Ub4LM6",
#             "owner_name": "Anthony Ruiz",
#             "phone": "(760) 630-8676",
#             "provider_name": "Sonia's Family Childcare"
#         },
#         {
#             "email": "070304@klcorp.com",
#             "id": "prvdrs_1BAWlSjl5lDRxtyHSVYkNNL7",
#             "owner_name": "Jennifer Hobson",
#             "phone": "(559) 438-7740",
#             "provider_name": "KinderCare Education LLC"
#         },
#         {
#             "email": "mont27@sbcglobal.net",
#             "id": "prvdrs_WpiaB5fDGpj2ISoNE1oDvnTO",
#             "owner_name": "Chester Reynolds",
#             "phone": "(760) 724-8955",
#             "provider_name": "Montessori School of Oceanside #2"
#         },
#         {
#             "email": "hhwatsonville@hhpreschool.com",
#             "id": "prvdrs_J39gPUnwKWWWaDiq3StLvhiA",
#             "owner_name": "Jack Gallagher",
#             "phone": "(831) 724-0175",
#             "provider_name": "Hearts And Hands Christian Childcare Center and Preschool"
#         },
#         {
#             "email": "Mnajafi74@yahoo.com",
#             "id": "prvdrs_jXNfLq3dtCKJg8G1dmXFzG62",
#             "owner_name": "Patricia Lajoie",
#             "phone": "(760) 598-5437",
#             "provider_name": "Kids Town Montessori School"
#         },
#         {
#             "email": "070349@klcorp.com",
#             "id": "prvdrs_jzNeh7oReC6y3AcwMwG35W5i",
#             "owner_name": "Lisette Hayes",
#             "phone": "(951) 681-1440",
#             "provider_name": "KinderCare Education LLC"
#         },
#         {
#             "email": "stephanie.gill@nlcinc.com",
#             "id": "prvdrs_JcxIs4Kc4iHlo6DTIJSLT5Ip",
#             "owner_name": "Jonathan Platner",
#             "phone": "(916) 683-3244",
#             "provider_name": "Merryhill School - Harbour Pt."
#         },
#         {
#             "email": "0234@childtime.com",
#             "id": "prvdrs_2Ys75wpNZnfSr05viLhXSt1k",
#             "owner_name": "Candice Flesher",
#             "phone": "(916) 783-0443",
#             "provider_name": "Childtime Children's Center @ Pleasant Grove"
#         },
#         {
#             "email": "iowabob@cox.net",
#             "id": "prvdrs_nrNGlO1yr7eRWB3TYlWuLvph",
#             "owner_name": "Son Chamberlain",
#             "phone": "(760) 940-1953",
#             "provider_name": "Sprowell, Elizabeth and Robert Family Child Care"
#         },
#         {
#             "email": "6216@tutortime.com",
#             "id": "prvdrs_2Dw8f7wTyKjkhkjarO1OZ4r8",
#             "owner_name": "James Arko",
#             "phone": "(619) 448-4445",
#             "provider_name": "Tutor Time Child Care Learning Center"
#         },
#         {
#             "email": "allsaintspreschool@sbcglobal.net",
#             "id": "prvdrs_pO3BKrsM5pUkwRDvlwfThP4Y",
#             "owner_name": "Frank Reese",
#             "phone": "(760) 598-8495",
#             "provider_name": "All Saints Preschool"
#         },
#         {
#             "email": "cmearig@shorelinebaptist.org",
#             "id": "prvdrs_n5wN9oVzDXBXP4tUsPFpqSlc",
#             "owner_name": "Marsha Tabor",
#             "phone": "(714) 962-6886",
#             "provider_name": "Shoreline Baptist Church/Shoreline Christian Preschool"
#         },
#         {
#             "email": "0204@childtime.com",
#             "id": "prvdrs_PR67qAgeFd1PSWPf4ZDUd8yW",
#             "owner_name": "Marie Fitzpatrick",
#             "phone": "(949) 495-4727",
#             "provider_name": "ChildTime Learning Center- Laguna Niguel"
#         },
#         {
#             "email": "cheriborger@vistausd.org",
#             "id": "prvdrs_WEMNh8z7Y6EPGu4VX5u0bKfg",
#             "owner_name": "Albert Brown",
#             "phone": "(760) 726-8179",
#             "provider_name": "VUSD AM-PM"
#         },
#         {
#             "email": "banderson@columbiasd.com",
#             "id": "prvdrs_tsAW193YOPv5XuC71QWHLams",
#             "owner_name": "Carolyn Short",
#             "phone": "(530) 223-3874",
#             "provider_name": "Columbia Elementary School District"
#         },
#         {
#             "email": "301736@klcorp.com",
#             "id": "prvdrs_fisI2YxvS9STIV2gvwlTsxZt",
#             "owner_name": "Brittany Kirkwood",
#             "phone": "(951) 789-4762",
#             "provider_name": "KinderCare Learning Center LLC"
#         },
#         {
#             "email": "andrabadon@cajonvalley.net",
#             "id": "prvdrs_P6BkgydMgXei6ceYl724c4jY",
#             "owner_name": "Gregory Sammarco",
#             "phone": "(619) 441-6172",
#             "provider_name": "Cajon Valley Union School"
#         },
#         {
#             "email": "0235@childtime.com",
#             "id": "prvdrs_1V2tUbnthyeOxIleoPOu23Tn",
#             "owner_name": "Nereida Ngo",
#             "phone": "(916) 791-2530",
#             "provider_name": "Childtime Children's Center"
#         },
#         {
#             "email": "info@scrippsmontessori.com",
#             "id": "prvdrs_AVrmZbLa7NTbzHVhG97ERrsH",
#             "owner_name": "Gary Everett",
#             "phone": "(858) 566-3632",
#             "provider_name": "Scripps Montessori School"
#         },
#         {
#             "email": "christieg@ywcaharbor.org",
#             "id": "prvdrs_IHCKJf8TC0GkbcLj0oLz6qhM",
#             "owner_name": "Jean Palmer",
#             "phone": "(310) 732-7697",
#             "provider_name": "World Tots LA"
#         },
#         {
#             "email": "301060@klcorp.com",
#             "id": "prvdrs_0oZSgSiyjuJ3bSWmSmY4PtmP",
#             "owner_name": "Corey March",
#             "phone": "(619) 588-5959",
# ...
#             "owner_name": "Gilberto Thomas",
#             "phone": "(858) 793-0071",
#             "provider_name": "DMUSD After School Program @ Sage Canyon"
#         },
#         {
#             "email": "monocananga@aol.com",
#             "id": "prvdrs_WhT3K6B6nzv1Yzay0uHifcVu",
#             "owner_name": "Christopher Stobb",
#             "phone": "(909) 396-7110",
#             "provider_name": "Hurtado Family Child Care"
#         },
#         {
#             "email": "loretta@evergreensb.com",
#             "id": "prvdrs_S9QJUIB11f4LlFRZFNanMBmN",
#             "owner_name": "Robert Barnes",
#             "phone": "(805) 685-7725",
#             "provider_name": "Evergreen Learning Center"
#         },
#         {
#             "email": "learningtree1642@yahoo.com",
#             "id": "prvdrs_646lhbhAk8TEQeFRKKm6ZEeo",
#             "owner_name": "Clarinda Johnson",
#             "phone": "(661) 400-5271",
#             "provider_name": "Learning Tree Montessori Preschool"
#         },
#         {
#             "email": "countryhillmontessori@gmail.com",
#             "id": "prvdrs_bFcxQQLXUQJC21Mm9p1ZUH1o",
#             "owner_name": "Cathi Conway",
#             "phone": "(916) 969-2929",
#             "provider_name": "Country Hill Montessori Inc"
#         },
#         {
#             "email": "amithmass@yahoo.com",
#             "id": "prvdrs_anuA2ZydobbF2vmWM6iP75CF",
#             "owner_name": "Francis Gray",
#             "phone": "(951) 272-2022",
#             "provider_name": "Sunrise Children's Center"
#         },
#         {
#             "email": "rohnertpark@tlechildcare.com",
#             "id": "prvdrs_tDoOUqD5e8FghFKWqulsqYPD",
#             "owner_name": "Robert Brooks",
#             "phone": "(707) 585-5992",
#             "provider_name": "The Learning Experience"
#         },
#         {
#             "email": "tinny.trots@gmail.com",
#             "id": "prvdrs_e8ckCo162pVWgibLqq2Y6L5w",
#             "owner_name": "Rhonda Lamoureux",
#             "phone": "(619) 832-6609",
#             "provider_name": "Kern, Gabriela Family Childcare"
#         },
#         {
#             "email": "jerryhale1302@yahoo.com",
#             "id": "prvdrs_Gqo7PEL3MxoYloeneAKLsvgk",
#             "owner_name": "Robert Mccrae",
#             "phone": "(310) 671-4246",
#             "provider_name": "Wiz Child Center Inc"
#         },
#         {
#             "email": "mariajeffrieschildcare@yahoo.com",
#             "id": "prvdrs_nhJt3NpJEfRdtlgGjVoVKTJy",
#             "owner_name": "Aaron Pleiman",
#             "phone": "(619) 756-7578",
#             "provider_name": "Jeffries, Maria Family Child Care"
#         },
#         {
#             "email": "sonjaperez101@gmail.com",
#             "id": "prvdrs_ddLXZ1HNjaGmx76ClXpfJWv3",
#             "owner_name": "Iris Bozeman",
#             "phone": "(650) 534-7596",
#             "provider_name": "Perez, Sonja Family Child Care"
#         },
#         {
#             "email": "admin@kmont.org",
#             "id": "prvdrs_1kYLErLrWfP6hgTRGjEEqKQc",
#             "owner_name": "Joseph Gonzalez",
#             "phone": "(949) 363-7373",
#             "provider_name": "Kensington Montessori School"
#         },
#         {
#             "email": "kim@nationalcitychurch.com",
#             "id": "prvdrs_rGJBmFEnzmADeU5BBUHsBkJR",
#             "owner_name": "Richard Sloan",
#             "phone": "(619) 259-2480",
#             "provider_name": "Adventure Point Early Learning Center"
#         },
#         {
#             "email": "alexis@littlebigtimecdc.com",
#             "id": "prvdrs_UXfLr7xjNHuAW9xVu8jacokn",
#             "owner_name": "Leo Baer",
#             "phone": "(916) 446-1200",
#             "provider_name": "Little Big Time Child Development Center"
#         },
#         {
#             "email": "tiphaniej@gmail.com",
#             "id": "prvdrs_J2gUmzvHXbcOia86r3FOBDt7",
#             "owner_name": "Joellen Kendall",
#             "phone": "(760) 213-7660",
#             "provider_name": "Kingdom Kidz Childcare"
#         },
#         {
#             "email": "jennjulz@sbcglobal.net",
#             "id": "prvdrs_LdgxTSlmUSHHRCYynBOWmWce",
#             "owner_name": "Kathy Carswell",
#             "phone": "(559) 737-8735",
#             "provider_name": "Luna, Jennifer Family Child Care"
#         },
#         {
#             "email": "alvarezcamila1987@gmail.com",
#             "id": "prvdrs_Yr3k5wqQaYO409qUb7m3JL38",
#             "owner_name": "Vanessa Lopez",
#             "phone": "(310) 591-6060",
#             "provider_name": "Alvarez Family Child Care"
#         },
#         {
#             "email": "nancy@beachbabies.com",
#             "id": "prvdrs_WQeJwGwW8zGDw8dYg2bgBSCm",
#             "owner_name": "Antonio Aldredge",
#             "phone": "(310) 322-8902",
#             "provider_name": "Beach Babies #4"
#         },
#         {
#             "email": "rpatterson@cityofsacramento.org",
#             "id": "prvdrs_ZxqtJs1pKf9Hw6n564I3Cwbr",
#             "owner_name": "Eda Williamson",
#             "phone": "(916) 277-6100",
#             "provider_name": "Bancroft 4th R"
#         },
#         {
#             "email": "info@mentoravenuepreschool.com",
#             "id": "prvdrs_xDYAfkwFin92gAr1q1In75sD",
#             "owner_name": "Kathleen Owen",
#             "phone": "(626) 396-7008",
#             "provider_name": "Mentor Preschool on Lake"
#         },
#         {
#             "email": "devinleahlstrand@aol.com",
#             "id": "prvdrs_9BGL8qD64mGjXCzGz9IgJAhA",
#             "owner_name": "Aurelio Stark",
#             "phone": "(714) 651-1295",
#             "provider_name": "Ahlstrand Family Child Care"
#         },
#         {
#             "email": "lauriepinkston@ymcala.org",
#             "id": "prvdrs_ByxH5pUE2kZ9bnGfaVP7hPNh",
#             "owner_name": "Wayne Ives",
#             "phone": "(818) 368-3231",
#             "provider_name": "YMCA of Metro Los Angeles/NV El Oro Way"
#         },
#         {
#             "email": "cynthia@inhercare.com",
#             "id": "prvdrs_YfOrq6215yJApnOqYx19lGpL",
#             "owner_name": "Jamie Cavender",
#             "phone": "(760) 492-4398",
#             "provider_name": "Yawn, Cynthia Family Child Care"
#         },
#         {
#             "email": "towneandcountryeec@gmail.com",
#             "id": "prvdrs_mFTUeqCDXa4Ng6Ol5hvuVKm4",
#             "owner_name": "Gertrude Pina",
#             "phone": "(714) 524-2780",
#             "provider_name": "Towne and Country Early Education Center"
#         },
#         {
#             "email": "director@primroselivermore.com",
#             "id": "prvdrs_InD443PqIsKwjX9H8EeoK3aP",
#             "owner_name": "Kellie Kim",
#             "phone": "(925) 215-7372",
#             "provider_name": "Primrose School Of Livermore"
#         },
#         {
#             "email": "bdfchildcare@gmail.com",
#             "id": "prvdrs_kXKGr7KAtXExaeorX9oHgxYo",
#             "owner_name": "Nicole Fitch",
#             "phone": "(951) 533-3294",
#             "provider_name": "Brighter Days Family Childcare"
#         },
#         {
#             "email": "jrutledge@roseville.ca.us",
#             "id": "prvdrs_CDdVGEu2lFIdMcnGA3Ekh3cF",
#             "owner_name": "Kimber Haynes",
#             "phone": "(916) 746-1260",
#             "provider_name": "Adventure Club School Age- Cirby School"
#         },
#         {
#             "email": "infomontessorivms@gmail.com",
#             "id": "prvdrs_CRWsP6hbJL7Za2aMHszdVnuf",
#             "owner_name": "Kristina Vasquez",
#             "phone": "(442) 333-9359",
#             "provider_name": "The Montessori Center"
#         },
#         {
#             "email": "nhale@sacwaldorf.org",
#             "id": "prvdrs_q9QYC2nPTKIsQ0UiLbIvdsIu",
#             "owner_name": "Adele Williams",
#             "phone": "(916) 860-2532",
#             "provider_name": "Sacramento Waldorf School"
#         },
#         {
#             "email": "melisa@carlsbaded.org",
#             "id": "prvdrs_mIYI6TxwcNVoQIEtcWm3WHls",
#             "owner_name": "Donald Taylor",
#             "phone": "(760) 331-5566",
#             "provider_name": "Carlsbad Educational Foundation- Kelly Elem."
#         },
#         {
#             "email": "diane.schneider@sanjuan.edu",
#             "id": "prvdrs_s4oVx6QjOz2USzQ5NvunE9hr",
#             "owner_name": "Nick Byrd",
#             "phone": "(916) 971-5941",
#             "provider_name": "Trajan Discovery Club-Trajan Elementary"
#         },
#         {
#             "email": "gbarriga@cdicdc.org",
#             "id": "prvdrs_fUuClg5eksBizbSOaUr4TJ9q",
#             "owner_name": "Maria Howard",
#             "phone": "(714) 357-7920",
#             "provider_name": "Oak Creek CDC"
#         },
#         {
#             "email": "gbarriga@cdicdc.org",
#             "id": "prvdrs_F3eUCMMrrH3dx8Ii1TR15tPf",
#             "owner_name": "Victor Bromley",
#             "phone": "(714) 357-7920",
#             "provider_name": "Callie Kirkpatrick CDC"
#         },
#         {
#             "email": "gbarriga@cdicdc.org",
#             "id": "prvdrs_OHjsasjpvOK8lfzcw3GuBZdC",
#             "owner_name": "Cathern Mauriello",
#             "phone": "(714) 357-7920",
#             "provider_name": "Southshore Child Development Center"
#         },
#         {
#             "email": "paolo@sterlingmontessori.net",
#             "id": "prvdrs_26E7zcmOuWHVO1LKQfSCLSoI",
#             "owner_name": "Olimpia Leone",
#             "phone": "(916) 434-7000",
#             "provider_name": "Sterling Montessori & Bambini Montessori"
#         },
#         {
#             "email": "paestey@yahoo.com",
#             "id": "prvdrs_V5Dgeqtgw7nwkaLf7cAVeWq5",
#             "owner_name": "Michael Stinnett",
#             "phone": "(916) 716-3760",
#             "provider_name": "Patricia Estey"
#         },
#         {
#             "email": "gbarriga@cdicdc.org",
#             "id": "prvdrs_CJGXl5qHA4yousVr0KokuAP2",
#             "owner_name": "Richard Desrochers",
#             "phone": "(714) 357-7920",
#             "provider_name": "Menifee Child Development Center"
#         },
#         {
#             "email": "katherinee@buildingkidz.com",
#             "id": "prvdrs_maXR7OWJhmqTrhk2kjqgcMYc",
#             "owner_name": "Anthony Weber",
#             "phone": "(831) 438-4813",
#             "provider_name": "Building Kidz of Scotts Valley"
#         },
#         {
#             "email": "gbarriga@cdicdc.org",
#             "id": "prvdrs_gNNbXmdKNBlUZImH5djvLVx6",
#             "owner_name": "Ward Kruger",
#             "phone": "(714) 357-7920",
#             "provider_name": "Oak Meadows CDC"
#         },
#         {
#             "email": "lajuana@swlckidz.org",
#             "id": "prvdrs_EomqBKTrhqTFd7Z1ILUrdI9h",
#             "owner_name": "Carmen Carroll",
#             "phone": "(310) 549-0303",
#             "provider_name": "Small World Learning CTR No 2"
#         },
#         {
#             "email": "mramos@cdicdc.org",
#             "id": "prvdrs_vseGOcMcR9TcUwUCnxRQ51RN",
#             "owner_name": "Irwin Caro",
#             "phone": "(530) 753-3808",
#             "provider_name": "Cesar Chavez School Age CDC"
#         },
#         {
#             "email": "misspatdc@aol.com",
#             "id": "prvdrs_MwGzEOhAIMQfynIPwm2RjWcW",
#             "owner_name": "Bernice Acosta",
#             "phone": "(916) 691-6821",
#             "provider_name": "Alexander, Patricia"
#         },
#         {
#             "email": "jvillafana@bigfutureschool.com",
#             "id": "prvdrs_U4xZ5PxQLEQZc8juUBaTxssu",
#             "owner_name": "Lisa Walker",
#             "phone": "(760) 744-3900",
#             "provider_name": "Big Future Charter Preschool"
#         },
#         {
#             "email": "davidt@buildingkidz.com",
#             "id": "prvdrs_fuMORyuw4sW8IUZdizEL8xFc",
#             "owner_name": "Mary Vowell",
#             "phone": "(916) 780-5437",
#             "provider_name": "Building Kidz School- Eureka"
#         },
#         {
#             "email": "juana.cortez@ymail.com",
#             "id": "prvdrs_9p67iy2OtOmMOhJRapasK9W3",
#             "owner_name": "Christine Taylor",
#             "phone": "(619) 475-2868",
#             "provider_name": "Cortez, Juana Family Child Care"
#         },
#         {
#             "email": "subsidy@kc-education.com",
#             "id": "prvdrs_9kOHidtrTzyCy1asQNFo5XGf",
#             "owner_name": "Carroll Carpenter",
#             "phone": "(503) 872-1464",
#             "provider_name": "KCE Champions LLC @ Growth Public Schools"
#         },
#         {
#             "email": "myfirststationdaycare@gmail.com",
#             "id": "prvdrs_NqZh06k9q9QZmKRGJQSIS3Bs",
#             "owner_name": "Frank Quach",
#             "phone": "(408) 595-1808",
#             "provider_name": "Isaza Sandra"
#         },
#         {
#             "email": "christinekutzner@bigfutureschool.com",
#             "id": "prvdrs_QQhVxxBLoj3oqnxhwOHiiiy2",
#             "owner_name": "Marlene Bird",
#             "phone": "(858) 883-2985",
#             "provider_name": "Big Future Preschool"
#         },
#         {
#             "email": "scholarship@rainbowrising.org",
#             "id": "prvdrs_9RLbUWUtvCPtAaFyKJnB7ls3",
#             "owner_name": "Margaret Mccoy",
#             "phone": "(949) 333-1488",
#             "provider_name": "Rainbow Rising \u0096 Cypress Village"
#         },
#         {
#             "email": "berlingfamilychildcare@gmail.com",
#             "id": "prvdrs_AAlsskv2CGefm9aiKzcUZsSu",
#             "owner_name": "Cecil Livengood",
#             "phone": "(951) 489-7486",
#             "provider_name": "Berling Family Child Care"
#         },
#         {
#             "email": "info@playologykids.com",
#             "id": "prvdrs_CG6I2xLD8861s134Hgk4pLmA",
#             "owner_name": "Lynn Brewer",
#             "phone": "(916) 853-5678",
#             "provider_name": "Play-Ology"
#         },
#         {
#             "email": "pequesfdc@icloud.com",
#             "id": "prvdrs_KQeuJ7pUNumPs9c1Hi19j4E1",
#             "owner_name": "Paul Rokusek",
#             "phone": "(707) 514-9112",
#             "provider_name": "Brenda Cuesta FCCH"
#         },
#         {
#             "email": "missmariaeg@gmail.com",
#             "id": "prvdrs_ly6bJsleIQZbXO6uJsKC2wDJ",
#             "owner_name": "Barbara Greenfeld",
#             "phone": "(408) 353-8695",
#             "provider_name": "Maria Gonzalez"
#         },
#         {
#             "email": "shamadrashid@gmail.com",
#             "id": "prvdrs_fFSPJfQ5eWfxPRchrCJOaOJt",
#             "owner_name": "James Lutz",
#             "phone": "(562) 337-4502",
#             "provider_name": "Rashid Family Child Care"
#         },
#         {
#             "email": "6499@tutortime.com",
#             "id": "prvdrs_Ie6KbJdHY5grl7vQdcO341kv",
#             "owner_name": "Mark Jones",
#             "phone": "(818) 710-1677",
#             "provider_name": "Tutor Time Learning Center"
#         },
#         {
#             "email": "ortegafamilyfour@gmail.com",
#             "id": "prvdrs_D3KmSegkIm4t7hBfmrXYyTyc",
#             "owner_name": "Wanda Becker",
#             "phone": "(626) 419-1858",
#             "provider_name": "Ortega Family Child Care"
#         },
#         {
#             "email": "subsidy@kc-education.com",
#             "id": "prvdrs_6NfAOQ6bTQPv56fNskH0RSfF",
#             "owner_name": "Allen Harder",
#             "phone": "(503) 872-1464",
#             "provider_name": "KCE Champions LLC @ Mason"
#         },
#         {
#             "email": "orcuttlee@yahoo.com",
#             "id": "prvdrs_KDnJgmvmAbwY13BUTZQYf6vY",
#             "owner_name": "Jason Moons",
#             "phone": "(805) 264-8234",
#             "provider_name": "Amy Lee Ulloa"
#         },
#         {
#             "email": "chapmanmontessori@gmail.com",
#             "id": "prvdrs_pDZIfFWzSKI97EvHotqqw1LR",
#             "owner_name": "Ana Drake",
#             "phone": "(714) 591-5927",
#             "provider_name": "Chapman Montessori School"
#         },
#         {
#             "email": "christena@sdkidventures.com",
#             "id": "prvdrs_akzHqvph9OyodWo6q7FxLBFB",
#             "owner_name": "Jill Stokes",
#             "phone": "(619) 573-9625",
#             "provider_name": "Kid Ventures Liberty Station Preschool"
#         },
#         {
#             "email": "preschool@oceanview.org",
#             "id": "prvdrs_56127MTi8TyyPofYDfOqBDw2",
#             "owner_name": "Melia Rodriguez",
#             "phone": "(310) 514-1048",
#             "provider_name": "Ocean View Pre-School"
#         }
#     ]
# }

# %%
# extract all data in the first element "providers"
data = response["providers"]
print(data)
# Out:
# [{'id': 'prvdrs_xTVZPYTrIzsRBVJojkuHkRh6', 'provider_name': 'La Rue Park Child Development Center', 'phone': '(530) 753-8716', 'email': 'snfaria@ucdavis.edu', 'owner_name': 'Elizabeth Wall'}, {'id': 'prvdrs_9XYNilFfFjGeJjWbjP2uvLje', 'provider_name': 'Carousel Preschool', 'phone': '(310) 216-6641', 'email': 'jane.uy@carouselschool.com', 'owner_name': 'Shaneka Kittrell'}, {'id': 'prvdrs_6fwq7dwGBVctHrZWbpBuZhWJ', 'provider_name': 'Adventure Club - Quail Glen', 'phone': '(916) 772-7529', 'email': 'jrutledge@roseville.ca.us', 'owner_name': 'Dewayne Bunning'}, {'id': 'prvdrs_8YF3tyi0eeqlJm1UIeOZVx68', 'provider_name': 'Adventure Club - Coyote Ridge', 'phone': '(916) 772-7271', 'email': 'vsisneroz@roseville.ca.us', 'owner_name': 'Ernest Edmondson'}, {'id': 'prvdrs_nH2OzYh77wA1vs2aXsMqfNLx', 'provider_name': 'Azusa Discovery Center', 'phone': '(626) 334-1806', 'email': 'jhdmaddox60@msn.com', 'owner_name': 'William Bliss'}, {'id': 'prvdrs_2iXXgefVvhsvGa3OXDPT6R4e', 'provider_name': "Light of Christ Children's Center", 'phone': '(760) 745-6849', 'email': 'jmoore@fumcesc.com', 'owner_name': 'Gilbert Hernandez'}, {'id': 'prvdrs_JPVynpwpZVNG93k5ke12F3Pm', 'provider_name': 'Little Peoples Corner Preschool/daycare', 'phone': '(707) 445-0339', 'email': 'lsfloren@yahoo.com', 'owner_name': 'Essie Fernandez'}, {'id': 'prvdrs_GoGNGJ1ZjWYWMVMv1jCAmwFX', 'provider_name': 'Kindercare Learning Center LLC', 'phone': '(916) 961-5599', 'email': '301027@klcorp.com', 'owner_name': 'James Middleton'}, {'id': 'prvdrs_bGYqJycansw3CycvVATrfpng', 'provider_name': 'Olive Knolls Christian School', 'phone': '(661) 393-3566', 'email': 'wmayes@okcs.us', 'owner_name': 'Gerald Sanyaro'}, {'id': 'prvdrs_YyqLv6sXMROfQ1GEtDH6Cs2h', 'provider_name': 'Peace Lutheran Early Childhood Education Center', 'phone': '(916) 927-4060', 'email': 'peacepreschool10@yahoo.com', 'owner_name': 'Nathan Currie'}, {'id': 'prvdrs_3VZjKNPtMGFJM8qhaEN1FdE9', 'provider_name': 'Kids on Campus', 'phone': '(760) 744-4776', 'email': 'carol.allen@smusd.org', 'owner_name': 'Alanna Schwartz'}, {'id': 'prvdrs_rVF4OIlRmKB8ha24qHNDPDuy', 'provider_name': 'West Redding Preschool', 'phone': '(530) 243-2225', 'email': 'westreddingpreschool@ymail.com', 'owner_name': 'Morris Budd'}, {'id': 'prvdrs_SJzhwEqni6r7OdZBxkJfLLjC', 'provider_name': 'Kiddie Academy Child Care Learning Center', 'phone': '(760) 439-5552', 'email': 'kiddieacademy1@aol.com', 'owner_name': 'Cesar Bowers'}, {'id': 'prvdrs_c7P1KK1md0UZELOxRG5pse2q', 'provider_name': 'KinderCare Learning Center LLC', 'phone': '(760) 745-2474', 'email': '300886@klcorp.com', 'owner_name': 'Shelley Thomas'}, {'id': 'prvdrs_PLWjgHvIOLKifKVJLzsZKHXl', 'provider_name': 'Action Day Learning Center', 'phone': '(916) 985-0976', 'email': 'Folsom@actiondaylearningcenter.com', 'owner_name': 'Oralia George'}, {'id': 'prvdrs_XcbQHdHfyoQe6MxTiICOchhx', 'provider_name': "Childtime Children's Center", 'phone': '(661) 665-7790', 'email': 'mmoreno@childtime.com', 'owner_name': 'Orville Nelson'}, {'id': 'prvdrs_haX2r5oPhQpy47f3v6h2SfVA', 'provider_name': 'La Quinta Preschool', 'phone': '(760) 564-2848', 'email': 'kmurphy@desertymca.org', 'owner_name': 'John Newhouse'}, {'id': 'prvdrs_xiYaQGY8q7BjCy9uPytT6YW3', 'provider_name': 'Heather Ridge Child Care Center', 'phone': '(530) 241-7226', 'email': 'hrcc1@sbcglobal.net', 'owner_name': 'June Rolling'}, {'id': 'prvdrs_eF47uaHsJqTj73rx92hL2qGR', 'provider_name': "Childtime Children's Center", 'phone': '(209) 551-0255', 'email': 'sstephens@childtime.com', 'owner_name': 'Robert Briscoe'}, {'id': 'prvdrs_pAuviSxNg3UbdlUvcxfj1XhA', 'provider_name': 'Adventure Club - Heritage Oak Elem. Sch.', 'phone': '(916) 773-3959', 'email': 'MLais@roseville.ca.us', 'owner_name': 'Jospeh Bateman'}, {'id': 'prvdrs_ZPVbGl36vx2fQ0373XigJEcw', 'provider_name': 'KinderCare Learning Center', 'phone': '(805) 494-5152', 'email': '000874@klcorp.com', 'owner_name': 'Tracy Karathanasis'}, {'id': 'prvdrs_CIgCoOMOns05e3Bb1CGRDJYG', 'provider_name': 'Girls Inc. O ...

# %%
# report the names
id_list = []
email_list = []
owner_name_list = []
phone_list = []
provider_name_list = []

# loop through each dictionary in the list and extract id, email, 
# owner name, phone, provider name and append to master list
for provider in data:
    id_list.append(provider['id'])
    email_list.append(provider['email'])
    owner_name_list.append(provider['owner_name'])
    phone_list.append(provider['phone'])
    provider_name_list.append(provider['provider_name'])

# %%
# convert data to dataframe 
child_care_center_df = pd.DataFrame({'id_1': id_list, 
                           'email': email_list,
                           'owner_name': owner_name_list,
                           'phone': phone_list,
                           'provider_name': provider_name_list})

# dataframe
child_care_center_df.head()
# Out:
#                               id_1                       email  \
# 0  prvdrs_xTVZPYTrIzsRBVJojkuHkRh6         snfaria@ucdavis.edu
# 1  prvdrs_9XYNilFfFjGeJjWbjP2uvLje  jane.uy@carouselschool.com
# 2  prvdrs_6fwq7dwGBVctHrZWbpBuZhWJ   jrutledge@roseville.ca.us
# 3  prvdrs_8YF3tyi0eeqlJm1UIeOZVx68   vsisneroz@roseville.ca.us
# 4  prvdrs_nH2OzYh77wA1vs2aXsMqfNLx         jhdmaddox60@msn.com
#
#          owner_name           phone                         provider_name
# 0    Elizabeth Wall  (530) 753-8716  La Rue Park Child Development Center
# 1  Shaneka Kittrell  (310) 216-6641                    Carousel Preschool
# 2   Dewayne Bunning  (916) 772-7529           Adventure Club - Quail Glen
# 3  Ernest Edmondson  (916) 772-7271         Adventure Club - Coyote Ridge
# 4     William Bliss  (626) 334-1806                Azusa Discovery Center

# %% [markdown]
# ## Run SQL in Jupyter Notebook

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
DB_ENDPOINT = "localhost"
DB = 'child_care_centers_db'
DB_USER = 'postgres'
DB_PASSWORD = #enter password here
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# Out:
# postgresql://postgres:postgres@localhost:5432/child_care_centers_db

# %%
# %sql $conn_string
# Out:
# 'Connected: postgres@child_care_centers_db'

# %% [markdown]
# ## Connect to local database

# %%
rds_connection_string = "postgres:postgres@localhost:5432/child_care_centers_db"

engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#check for tables
engine.table_names()
# Out:
# ['api_table', 'csv_table']

# %%
#put dataframe into postgreSQL
child_care_center_df.to_sql(name='api_table', con=engine, if_exists='append', index=False)

# %% [markdown]
# ## Confirm data has been added by querying the `api_table` table

# %%
#read from sql
pd.read_sql_query('select * from api_table', con=engine).head()
# Out:
#    id                             id_1                       email  \
# 0   1  prvdrs_xTVZPYTrIzsRBVJojkuHkRh6         snfaria@ucdavis.edu
# 1   2  prvdrs_9XYNilFfFjGeJjWbjP2uvLje  jane.uy@carouselschool.com
# 2   3  prvdrs_6fwq7dwGBVctHrZWbpBuZhWJ   jrutledge@roseville.ca.us
# 3   4  prvdrs_8YF3tyi0eeqlJm1UIeOZVx68   vsisneroz@roseville.ca.us
# 4   5  prvdrs_nH2OzYh77wA1vs2aXsMqfNLx         jhdmaddox60@msn.com
#
#          owner_name           phone                         provider_name
# 0    Elizabeth Wall  (530) 753-8716  La Rue Park Child Development Center
# 1  Shaneka Kittrell  (310) 216-6641                    Carousel Preschool
# 2   Dewayne Bunning  (916) 772-7529           Adventure Club - Quail Glen
# 3  Ernest Edmondson  (916) 772-7271         Adventure Club - Coyote Ridge
# 4     William Bliss  (626) 334-1806                Azusa Discovery Center
